# %% [markdown]
# # Benchmark: Performance & Automatic Denoising
#
# This notebook benchmarks the **`RandomizedSVD`** class wrapper against standard solutions. We evaluate two main aspects:
#
# 1. **Scalability:** Comparing execution time against the standard deterministic SVD (`numpy.linalg.svd`) as matrix size increases.
# 2. **Automatic Denoising:** Evaluating the accuracy of the **Gavish-Donoho** rank selection ('auto' mode) and its computational overhead compared to manual rank selection.

# %%
import sys
import os
import time
import numpy as np
import matplotlib.pyplot as plt

# Add parent directory to path to import the local library
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))

# Import the Wrapper Class
from randomized_svd import RandomizedSVD

# Plotting Style
plt.style.use('seaborn-v0_8-whitegrid')
plt.rcParams['figure.figsize'] = [12, 6]
plt.rcParams['font.size'] = 12

def benchmark_timer(model, X):
    """Helper to time the fit method."""
    start = time.perf_counter()
    model.fit(X)
    end = time.perf_counter()
    return end - start

print(f"NumPy Version: {np.__version__}")
# Out:
# NumPy Version: 2.4.0

# %% [markdown]
# ## 1. Scalability (Speed Benchmark)
#
# We compare the standard **Full SVD** (NumPy/LAPACK) against our **Randomized SVD** (Manual Mode).
# We fix the target rank to $k = 50$.
#
# * **Hypothesis:** `RandomizedSVD` should scale linearly with matrix size $n$, while `numpy.linalg.svd` should scale cubically ($\mathcal{O}(n^3)$).

# %%
# Parameters
matrix_sizes = [500, 1000, 2000, 3000, 4000, 5000]
fixed_k = 50

times_rsvd = []
times_numpy = []

print(f"{'Matrix Size':<15} | {'rSVD (Manual) s':<18} | {'NumPy Full s':<15} | {'Speedup':<10}")
print("-" * 70)

for n in matrix_sizes:
    # Generate random matrix
    np.random.seed(42)
    X = np.random.randn(n, n)
    
    # 1. Randomized SVD (Manual)
    # We use the wrapper class
    rsvd_model = RandomizedSVD(n_components=fixed_k, rank_selection='manual', random_state=42)
    t_rsvd = benchmark_timer(rsvd_model, X)
    times_rsvd.append(t_rsvd)
    
    # 2. NumPy Full SVD
    # We use explicit numpy call as baseline
    start = time.perf_counter()
    np.linalg.svd(X, full_matrices=False)
    t_numpy = time.perf_counter() - start
    times_numpy.append(t_numpy)
    
    speedup = t_numpy / t_rsvd
    print(f"{n}x{n:<11} | {t_rsvd:.4f}             | {t_numpy:.4f}          | {speedup:.1f}x")

# Plotting
plt.figure()
plt.plot(matrix_sizes, times_numpy, 'o--', color='firebrick', label='NumPy Full SVD (LAPACK)')
plt.plot(matrix_sizes, times_rsvd, 's-', color='forestgreen', linewidth=2, label=f'RandomizedSVD (k={fixed_k})')

plt.title(f'Scalability: Randomized vs Full SVD (Fixed Rank k={fixed_k})', fontsize=14)
plt.xlabel('Matrix Dimension (N)', fontsize=12)
plt.ylabel('Time (seconds)', fontsize=12)
plt.legend()
plt.grid(True, alpha=0.3)
plt.show()
# Out:
# Matrix Size     | rSVD (Manual) s    | NumPy Full s    | Speedup
# ----------------------------------------------------------------------
# 500x500         | 0.0060             | 0.0372          | 6.2x
# 1000x1000        | 0.0143             | 0.1919          | 13.4x
# 2000x2000        | 0.0219             | 2.3219          | 105.8x
# 3000x3000        | 0.0434             | 8.7709          | 201.9x
# 4000x4000        | 0.0490             | 20.2198          | 412.5x
# 5000x5000        | 0.0750             | 38.3952          | 512.0x

# %% [markdown]
# ## 2. Automatic Rank Selection (Gavish-Donoho)
#
# Here we evaluate the unique feature of this library: **`rank_selection='auto'`**.
#
# We simulate a common scenario:
#
# 1. **Signal:** A matrix with a true hidden rank of **20**.
# 2. **Noise:** We add significant white noise.
# 3. **The Challenge:** We ask the algorithm to look for up to **100** components.
# * **Manual Mode:** Will blindly return 100 components (capturing 80 dimensions of pure noise).
# * **Auto Mode:** Should automatically detect the cut-off at ~20 and discard the noise.

# %%
from randomized_svd import optimal_threshold

# Parameters
n = 2000
true_rank = 20
upper_bound_k = 100
noise_sigma = 0.5

print(f"Generating Signal (Rank {true_rank}) + Noise Matrix ({n}x{n})...")
np.random.seed(99)

U_true, _ = np.linalg.qr(np.random.randn(n, true_rank))
V_true, _ = np.linalg.qr(np.random.randn(n, true_rank))
S_true = np.diag(np.linspace(100, 60, true_rank)) 
X_clean = U_true @ S_true @ V_true.T

# Add Noise
X_noisy = X_clean + noise_sigma * np.random.randn(n, n)

print("\n--- Running Comparisons ---")

# 1. Manual Mode
model_manual = RandomizedSVD(n_components=upper_bound_k, rank_selection='manual', random_state=42)
time_manual = benchmark_timer(model_manual, X_noisy)
rank_manual = model_manual.n_components_

# 2. Auto Mode
model_auto = RandomizedSVD(n_components=upper_bound_k, rank_selection='auto', sigma=noise_sigma, random_state=42)
time_auto = benchmark_timer(model_auto, X_noisy)
rank_auto = model_auto.n_components_

# 3. Results Analysis
print(f"\n{'Metric':<25} | {'Manual Mode':<15} | {'Auto Mode':<15}")
print("-" * 60)
print(f"{'Execution Time':<25} | {time_manual:.4f} s        | {time_auto:.4f} s")
print(f"{'Detected/Kept Rank':<25} | {rank_manual:<15} | {rank_auto:<15} (True: {true_rank})")

overhead = (time_auto - time_manual) * 1000
print(f"\nComputational Overhead of 'Auto' logic: {overhead:.2f} milliseconds")

# --- Visualizing the Spectrum ---
plt.figure(figsize=(10, 6))

all_singular_values = model_manual.singular_values_
plt.plot(all_singular_values, 'o-', color='gray', alpha=0.5, label='Noisy Spectrum', markersize=4)

thresh = optimal_threshold(n, n, all_singular_values, sigma=noise_sigma)

plt.axhline(y=thresh, color='red', linestyle='--', label=rf'Threshold $\tau$ ({thresh:.2f})')
plt.axvline(x=true_rank-1, color='green', linestyle=':', label=f'True Rank ({true_rank})')
plt.plot(range(rank_auto), model_auto.singular_values_, 'o', color='dodgerblue', label='Kept Signal')

plt.title(rf'Automatic Denoising (Known $\sigma$={noise_sigma})', fontsize=14)
plt.legend()
plt.grid(True, alpha=0.3)
plt.show()
# Out:
# Generating Signal (Rank 20) + Noise Matrix (2000x2000)...
#
# --- Running Comparisons ---
#
# Metric                    | Manual Mode     | Auto Mode
# ------------------------------------------------------------
# Execution Time            | 0.0395 s        | 0.0390 s
# Detected/Kept Rank        | 100             | 15              (True: 20)
#
# Computational Overhead of 'Auto' logic: -0.53 milliseconds

# %% [markdown]
# ## Minka's MLE vs. Gavish-Donoho
#
# A common question is how the **Gavish-Donoho** method (used in this library) compares to the **Maximum Likelihood Estimation (MLE)** available in Scikit-Learn's standard `PCA` via `n_components='mle'`.
#
# While MLE is a powerful probabilistic method for estimating the underlying dimensionality of data, it has two main limitations in the context of this library:
# 1.  **No Sparse Support:** Scikit-Learn's MLE implementation does not support sparse input matrices (`scipy.sparse`), making it unusable for large-scale NLP or Recommender System datasets without densifying the data.
# 2.  **Objective Function:** MLE aims to recover the *generative* rank (structure), whereas Gavish-Donoho aims to minimize the *reconstruction error* (denoising).
#
# The following experiment compares the two methods on a synthetic dataset with a known rank but a low Signal-to-Noise Ratio (high noise).

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from randomized_svd import RandomizedSVD

# 1. Create a synthetic dataset: Low-Rank Signal + Noise
np.random.seed(42)
N, M = 1000, 500
true_rank = 100
sigma_noise = 5.0

# Generate Signal Matrix (Rank = 100)
U_true = np.random.randn(N, true_rank)
V_true = np.random.randn(M, true_rank)
X_signal = U_true @ V_true.T

# Add Gaussian Noise
X_noise = np.random.randn(N, M) * sigma_noise  # (Rank = 500)
X_full = X_signal + X_noise  # (Rank = max(500,100) = 500)

print(f"Dataset shape: {X_full.shape}, True Rank: {true_rank}")

# 2. Run Sklearn PCA with Minka's MLE
# Note: This only works because X_full is DENSE. It would crash on sparse data.
print("Running Sklearn PCA (MLE)...")
pca_mle = PCA(n_components='mle', svd_solver='full')
pca_mle.fit(X_full)
k_mle = pca_mle.n_components_
print(f"-> Minka's MLE selected rank: {k_mle}")

# 3. Run RandomizedSVD with Gavish-Donoho
print("Running RandomizedSVD (Auto)...")
# We set n_components=200 as a computational buffer/ceiling
rsvd_gd = RandomizedSVD(n_components=200, rank_selection='auto', random_state=42)
rsvd_gd.fit(X_full)
k_gd = rsvd_gd.n_components_
print(f"-> Gavish-Donoho selected rank: {k_gd}")

# 4. Plot Results
plt.figure(figsize=(10, 6))

# Use the full spectrum from standard PCA to visualize the entire curve
# (rsvd_gd only stores the truncated values)
all_singular_values = pca_mle.singular_values_

plt.plot(np.arange(len(all_singular_values)), all_singular_values, 
         'k.', alpha=0.3, label='Full Singular Value Spectrum')

# Minka MLE Cutoff
plt.axvline(x=k_mle, color='blue', linestyle='--', linewidth=2, 
            label=f"Minka MLE (k={k_mle}) - Structure Recovery")

# Gavish-Donoho Cutoff
plt.axvline(x=k_gd, color='red', linestyle='-', linewidth=2, 
            label=f"Gavish-Donoho (k={k_gd}) - Optimal Denoising")

# True Rank
plt.axvline(x=true_rank, color='green', linestyle=':', linewidth=2, 
            label=f"True Signal Rank (k={true_rank})")

plt.title("Rank Selection Comparison: MLE vs Gavish-Donoho (High Noise)")
plt.xlabel("Rank Index")
plt.ylabel("Singular Value (log scale)")
plt.yscale('log')
plt.legend()
plt.grid(True, which='both', linestyle='--', alpha=0.5)
plt.show()

# Text Analysis
print("-" * 30)
print(f"True Rank: {true_rank}")
print(f"Gavish-Donoho Selection: {k_gd} (Difference: {k_gd - true_rank})")
print(f"Minka MLE Selection:     {k_mle} (Difference: {k_mle - true_rank})")
# Out:
# Dataset shape: (1000, 500), True Rank: 100
# Running Sklearn PCA (MLE)...
# -> Minka's MLE selected rank: 100
# Running RandomizedSVD (Auto)...
# -> Gavish-Donoho selected rank: 59
# ------------------------------
# True Rank: 100
# Gavish-Donoho Selection: 59 (Difference: -41)
# Minka MLE Selection:     100 (Difference: 0)

# %% [markdown]
# ### Interpretation of Results
#
# The results above highlight a fundamental philosophical difference between the two approaches:
#
# * **Minka's MLE (Structure Recovery):** In the example above, MLE correctly identifies the *true rank* (e.g., 100). It successfully detects that there are 100 underlying vectors generating the data, even if the last ones are heavily corrupted by noise.
# * **Gavish-Donoho (Optimal Denoising):** This method typically selects a lower rank (e.g., ~60). It truncates the "tail" components because, although they contain real signal, that signal is overwhelmed by noise. Keeping them would mathematically increase the Mean Squared Error (MSE) of the reconstruction.
#
# **The Verdict:**
# * If your goal is to know **"how many distinct sources generated this data?"**, MLE is often more accurate in high-noise regimes.
# * If your goal is **"which components should I keep to get the cleanest possible signal for my downstream model?"**, Gavish-Donoho is superior as it filters out components with an effective SNR < 1.
# * **Crucially**, if your data is **sparse**, `randomized-svd` is the only option, as MLE is strictly limited to dense arrays in the Scikit-Learn ecosystem.
