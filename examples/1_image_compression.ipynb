# %% [markdown]
# # Image Compression & Denoising with rSVD
#
# In this notebook, we investigate how Randomized SVD behaves on real-world visual data.
#
# 1. **Compression:** Using `rank_selection='manual'` to trade detail for size.
# 2. **Denoising Analysis:** Using `rank_selection='auto'` (Gavish-Donoho) to remove noise, and analyzing why mathematically optimal denoising doesn't always mean visually perfect results.

# %%
import sys
import os
import time
import numpy as np
import matplotlib.pyplot as plt
from scipy import datasets

# Add project root to path
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))

# Use the Wrapper
from randomized_svd import RandomizedSVD
# Import threshold function for visualization later
from randomized_svd.threshold import optimal_threshold, optimal_rank

# 1. Load & Normalize Image to [0.0, 1.0]
try:
    img_raw = datasets.face(gray=True)
except AttributeError:
    img_raw = datasets.ascent()

img = img_raw.astype(np.float64) / 255.0
M, N = img.shape

print(f"Original Image Shape: {M}x{N}")

plt.figure(figsize=(5, 5))
plt.imshow(img, cmap='gray')
plt.title("Original High-Res")
plt.axis('off')
plt.show()
# Out:
# Original Image Shape: 768x1024

# %% [markdown]
# ## 1. Image Compression (Manual Rank)
#
# We manually force the image into smaller subspaces. This demonstrates how SVD prioritizes global structure over fine detail.

# %%
ranks = [10, 50, 150]
plt.figure(figsize=(16, 5))

# Plot Original
plt.subplot(1, 4, 1)
plt.imshow(img, cmap='gray')
plt.title("Original")
plt.axis('off')

for i, k in enumerate(ranks):
    # Manual Mode
    model = RandomizedSVD(n_components=k, rank_selection='manual', random_state=42)
    img_reduced = model.fit_transform(img)
    img_approx = model.inverse_transform(img_reduced)
    
    # Calculate Ratio (using float64 size)
    original_size = img.size
    compressed_size = (M * k) + k + (k * N)
    ratio = original_size / compressed_size
    
    plt.subplot(1, 4, i + 2)
    plt.imshow(img_approx, cmap='gray')
    plt.title(f"Rank {k}\nRatio: {ratio:.1f}x")
    plt.axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 2. Automatic Denoising Analysis
#
# We corrupt the image with known Gaussian noise ($\sigma = 0.1$).
# We then use `rank_selection='auto'` to let the **Gavish-Donoho** algorithm find the optimal hard threshold to remove this noise.
#
# **The Goal:** Understand the trade-off between noise removal and detail preservation.

# %%
# --- 1. Data Generation (Synthetic Low-Rank Signal) ---
# Based on Brunton & Kutz, Data-Driven Science and Engineering
np.random.seed(42)
M = 200  # Image size (MxM)
N = M

# Create time vector
t = np.linspace(-3, 3, M)

# Create low-rank signal components (Rank 2)
Utrue = np.column_stack([
    np.cos(17*t) * np.exp(-t**2),
    np.sin(11*t)
])
Vtrue = np.column_stack([
    np.sin(5*t) * np.exp(-t**2),
    np.cos(13*t)
])
Strue = np.diag([2.0, 0.5])

# Construct the clean image
img = Utrue @ Strue @ Vtrue.T

# Normalize to [0, 1] for consistent display/noise handling
img = (img - img.min()) / (img.max() - img.min())

# Add Gaussian Noise
noise_sigma = 0.10  # 10% Noise
noisy_img = img + noise_sigma * np.random.randn(M, N)
noisy_img_disp = np.clip(noisy_img, 0.0, 1.0) # Clip for display only

# --- 2. Analysis & Denoising ---

# A) Manual Analysis (to capture the FULL spectrum including noise tail)
# We calculate a large buffer manually to visualize the "discarded" noise
buffer_rank = 100 
analyzer = RandomizedSVD(
    n_components=buffer_rank, 
    rank_selection='manual', 
    random_state=42
)
analyzer.fit(noisy_img)
s_full_spectrum = analyzer.singular_values_

# B) Calculate Gavish-Donoho Thresholds
tau = optimal_threshold(M, N, s_full_spectrum, sigma=noise_sigma)
k_opt = optimal_rank(M, N, s_full_spectrum, sigma=noise_sigma)

# C) Perform Denoising (Auto Mode)
# Using a fresh instance to demonstrate the 'auto' workflow
denoiser = RandomizedSVD(
    n_components=buffer_rank, 
    rank_selection='auto', 
    sigma=noise_sigma, 
    random_state=42
)
img_denoised = denoiser.fit_transform(noisy_img)
img_denoised = denoiser.inverse_transform(img_denoised)


# --- 3. VISUALIZATION ---
fig = plt.figure(figsize=(15, 10))

# --- TOP ROW: IMAGES (1x3 Grid) ---

# A) Original Ground Truth
ax1 = plt.subplot(2, 3, 1)
ax1.imshow(img, cmap='gray')
ax1.set_title("A) Original Signal (Rank 2)", fontsize=11)
ax1.axis('off')

# B) Noisy Input
ax2 = plt.subplot(2, 3, 2)
ax2.imshow(noisy_img_disp, cmap='gray')
ax2.set_title(rf"B) Corrupted Input ($\sigma$={noise_sigma})", fontsize=11)
ax2.axis('off')

# C) Restored Output
ax3 = plt.subplot(2, 3, 3)
ax3.imshow(np.clip(img_denoised, 0.0, 1.0), cmap='gray')
ax3.set_title(f"C) Gavish–Donoho Restored (Rank {k_opt})", fontsize=11)
ax3.axis('off')

# --- BOTTOM ROW: SPECTRUM (Full Width) ---
ax4 = plt.subplot(2, 1, 2)

# Plot full noise spectrum (gray)
ax4.semilogy(
    s_full_spectrum, 'o-', 
    color='gray', alpha=0.4, markersize=3, 
    label='Noise Tail (Discarded)'
)

# Overlay kept signal spectrum (blue)
ax4.semilogy(
    range(k_opt), s_full_spectrum[:k_opt], 'o', 
    color='dodgerblue', markersize=5, 
    label=f'Signal (Kept Rank {k_opt})'
)

# Plot Threshold Line
ax4.axhline(
    y=tau, color='red', linestyle='--', linewidth=2, 
    label=rf'Gavish–Donoho Threshold ($\tau \approx {tau:.2f}$)'
)

# Formatting
ax4.set_title("D) The Spectral Threshold: Automatically separating Signal from Noise", fontsize=12)
ax4.set_xlabel("Singular Value Index", fontsize=10)
ax4.set_ylabel("Magnitude (log scale)", fontsize=10)
ax4.legend(loc='upper right', fontsize=10)
ax4.grid(True, which='both', alpha=0.3, linestyle='--')
ax4.set_xlim(-2, 50) # Zoom in on the head of the spectrum

# Annotate Noise Floor
if k_opt + 5 < len(s_full_spectrum):
    ax4.annotate(
        'Noise Floor',
        xy=(k_opt + 5, s_full_spectrum[k_opt + 5]),
        xytext=(k_opt + 15, s_full_spectrum[k_opt + 5] * 5),
        arrowprops=dict(facecolor='black', arrowstyle='->'),
        fontsize=9
    )

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Analysis of Results
#
# Look at **Image B** and **Plot C**.
#
# * The algorithm successfully removed the grainy noise.
# * However, the image appears softer/blurrier than the original.
#
# **Why? Look at Plot C.**
# The red dashed line is the mathematically optimal threshold for removing Gaussian noise.
# The algorithm keeps the blue dots (strong signal) and discards everything below the line.
#
# Unfortunately, **fine textures (like fur) reside in the same "tail" of the spectrum as the noise**. The hard threshold inevitably cuts away these details along with the noise. This confirms the library is working correctly mathematically, but highlights the inherent challenge of denoising visual data with hard thresholding.
